# %%
import pandas as pd

# %%
df = pd.read_csv('spy_wide_strikes_default_2023-09-01_to_2025-08-30_schema.csv')

# %%
pd.set_option('display.max_rows', 215)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Column       215 non-null    object
#  1   Type         215 non-null    object
#  2   Description  215 non-null    object
# dtypes: object(3)
# memory usage: 5.2+ KB

# %%
df
# Out:
#                        Column     Type  \
# 0                        date   object
# 1                    spy_open  float64
# 2                    spy_high  float64
# 3                     spy_low  float64
# 4                   spy_close  float64
# 5          spy_close_prev_day  float64
# 6                  spy_volume  float64
# 7             expiration_date   object
# 8                  atm_strike    int64
# 9             atm_call_ticker   object
# 10              atm_call_open  float64
# 11              atm_call_high  float64
# 12               atm_call_low  float64
# 13             atm_call_close  float64
# 14            atm_call_volume    int64
# 15              atm_call_vwap  float64
# 16         atm_call_prev_open  float64
# 17        atm_call_prev_close  float64
# 18       atm_call_prev_volume    int64
# 19         atm_call_prev_vwap  float64
# 20             atm_put_ticker   object
# 21               atm_put_open  float64
# 22               atm_put_high  float64
# ...

# %%
df
# Out:
#                        Column     Type  \
# 0                        date   object
# 1                    spy_open  float64
# 2                    spy_high  float64
# 3                     spy_low  float64
# 4                   spy_close  float64
# 5          spy_close_prev_day  float64
# 6                  spy_volume  float64
# 7             expiration_date   object
# 8                  atm_strike    int64
# 9             atm_call_ticker   object
# 10              atm_call_open  float64
# 11              atm_call_high  float64
# 12               atm_call_low  float64
# 13             atm_call_close  float64
# 14            atm_call_volume    int64
# 15              atm_call_vwap  float64
# 16         atm_call_prev_open  float64
# 17        atm_call_prev_close  float64
# 18       atm_call_prev_volume    int64
# 19         atm_call_prev_vwap  float64
# 20             atm_put_ticker   object
# 21               atm_put_open  float64
# 22               atm_put_high  float64
# ...

# %%
df
# Out:
#                        Column     Type  \
# 0                        date   object
# 1                    spy_open  float64
# 2                    spy_high  float64
# 3                     spy_low  float64
# 4                   spy_close  float64
# 5          spy_close_prev_day  float64
# 6                  spy_volume  float64
# 7             expiration_date   object
# 8                  atm_strike    int64
# 9             atm_call_ticker   object
# 10              atm_call_open  float64
# 11              atm_call_high  float64
# 12               atm_call_low  float64
# 13             atm_call_close  float64
# 14            atm_call_volume    int64
# 15              atm_call_vwap  float64
# 16         atm_call_prev_open  float64
# 17        atm_call_prev_close  float64
# 18       atm_call_prev_volume    int64
# 19         atm_call_prev_vwap  float64
# 20             atm_put_ticker   object
# 21               atm_put_open  float64
# 22               atm_put_high  float64
# ...

# %%
df.loc[:, :]
# Out:
#            date  spy_open  spy_high   spy_low  spy_close  spy_close_prev_day  \
# 0    2023-09-05    450.73    451.06  449.1700     449.24              451.19
# 1    2023-09-06    448.40    448.51  443.8100     446.22              449.24
# 2    2023-09-07    443.11    445.55  442.7500     444.85              446.22
# 3    2023-09-08    444.90    447.11  444.5300     445.52              444.85
# 4    2023-09-11    448.24    448.77  446.4699     448.45              445.52
# ..          ...       ...       ...       ...        ...                 ...
# 494  2025-08-25    644.04    645.29  642.3500     642.47              645.31
# 495  2025-08-26    642.20    645.51  641.5700     645.16              642.47
# 496  2025-08-27    644.57    647.37  644.4200     646.63              645.16
# 497  2025-08-28    647.24    649.48  645.3400     648.92              646.63
# 498  2025-08-29    647.47    647.84  643.1400     645.05              648.92
#
# ...

# %%
df= pd.read_csv('spy_wide_strikes_default_2023-09-01_to_2025-08-30.csv')

# %%
df_schema= pd.read_csv('spy_wide_strikes_default_2023-09-01_to_2025-08-30_schema.csv')

# %%
atm_open = df.loc[:,'atm_call_open']

# %%
atm_close = df.loc[:, 'atm_call_close']

# %%
print(atm_open.mean(), atm_close.mean())
# Out:
# 2.0202204408817637 2.0464529058116234
