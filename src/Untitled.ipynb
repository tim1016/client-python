# %%
import pandas as pd

# %%
df = pd.read_csv('spy_options_default_grouping_2024-12-28_to_2025-08-28.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 98 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 165 non-null    object
#  1   spy_open             165 non-null    float64
#  2   spy_high             165 non-null    float64
#  3   spy_low              165 non-null    float64
#  4   spy_close            165 non-null    float64
#  5   spy_close_prev_day   165 non-null    float64
#  6   spy_volume           165 non-null    float64
#  7   expiration_date      165 non-null    object
#  8   atm_strike           165 non-null    int64
#  9   atm_call_ticker      165 non-null    object
#  10  atm_call_open        165 non-null    float64
#  11  atm_call_high        165 non-null    float64
#  12  atm_call_low         165 non-null    float64
#  13  atm_call_close       165 non-null    float64
#  14  atm_call_volume      165 non-null    int64
# ...

# %%
df
# Out:
#            date  spy_open  spy_high  spy_low  spy_close  spy_close_prev_day  \
# 0    2024-12-31   589.905  590.6399   584.42     586.08              588.22
# 1    2025-01-02   589.390  591.1300   580.50     584.64              586.08
# 2    2025-01-03   587.530  592.6000   586.43     591.95              584.64
# 3    2025-01-06   596.270  599.7000   593.60     595.36              591.95
# 4    2025-01-07   597.420  597.7500   586.78     588.63              595.36
# ..          ...       ...       ...      ...        ...                 ...
# 160  2025-08-22   637.760  646.5000   637.25     645.31              635.55
# 161  2025-08-25   644.040  645.2900   642.35     642.47              645.31
# 162  2025-08-26   642.200  645.5100   641.57     645.16              642.47
# 163  2025-08-27   644.570  647.3700   644.42     646.63              645.16
# 164  2025-08-28   647.240  649.4800   645.34     648.92              646.63
#
# ...

# %%
df2= pd.read_csv('spy_options_snapshots_20250822_to_20250829.csv')

# %%
df2.shape
# Out:
# (59276, 29)

# %%
df2
# Out:
#              date                ticker contract_type exercise_style  \
# 0      2025-08-18  O:SPY250829C00315000          call       american
# 1      2025-08-18  O:SPY250829C00320000          call       american
# 2      2025-08-18  O:SPY250829C00325000          call       american
# 3      2025-08-18  O:SPY250829C00330000          call       american
# 4      2025-08-18  O:SPY250829C00335000          call       american
# ...           ...                   ...           ...            ...
# 59271  2025-08-26  O:SPY271217P00980000           put       american
# 59272  2025-08-26  O:SPY271217P00985000           put       american
# 59273  2025-08-26  O:SPY271217P00990000           put       american
# 59274  2025-08-26  O:SPY271217P00995000           put       american
# 59275  2025-08-26  O:SPY271217P01000000           put       american
#
#       expiration_date  shares_per_contract  strike_price  day_change  \
# ...

# %%
df['underlying_last_update']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/client-python/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'underlying_last_update'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 98 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 165 non-null    object
#  1   spy_open             165 non-null    float64
#  2   spy_high             165 non-null    float64
#  3   spy_low              165 non-null    float64
#  4   spy_close            165 non-null    float64
#  5   spy_close_prev_day   165 non-null    float64
#  6   spy_volume           165 non-null    float64
#  7   expiration_date      165 non-null    object
#  8   atm_strike           165 non-null    int64
#  9   atm_call_ticker      165 non-null    object
#  10  atm_call_open        165 non-null    float64
#  11  atm_call_high        165 non-null    float64
#  12  atm_call_low         165 non-null    float64
#  13  atm_call_close       165 non-null    float64
#  14  atm_call_volume      165 non-null    int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59276 entries, 0 to 59275
# Data columns (total 29 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             59276 non-null  object
#  1   ticker                           59276 non-null  object
#  2   contract_type                    59276 non-null  object
#  3   exercise_style                   59276 non-null  object
#  4   expiration_date                  59276 non-null  object
#  5   shares_per_contract              59276 non-null  int64
#  6   strike_price                     59276 non-null  float64
#  7   day_change                       50680 non-null  float64
#  8   day_change_percent               50680 non-null  float64
#  9   day_close                        51408 non-null  float64
#  10  day_high                         51408 non-null  float64
#  11  day_low                          51408 non-null  float64
# ...

# %%
day_vol_gt_100 = (df2['day_volume'] > 10000)

# %%
df3=df2.loc[day_vol_gt_100,]

# %%
df4=df3.sort_values(by='day_volume', ascending=False)

# %%
df4.shape
# Out:
# (721, 29)

# %%
df5=df4[0:100]

# %%
df5
# Out:
#              date                ticker contract_type exercise_style  \
# 146    2025-08-18  O:SPY250829C00645000          call       american
# 34018  2025-08-22  O:SPY250829C00645000          call       american
# 17082  2025-08-20  O:SPY250829C00645000          call       american
# 42486  2025-08-25  O:SPY250829C00645000          call       american
# 50954  2025-08-26  O:SPY250829C00645000          call       american
# ...           ...                   ...           ...            ...
# 17087  2025-08-20  O:SPY250829C00650000          call       american
# 50959  2025-08-26  O:SPY250829C00650000          call       american
# 151    2025-08-18  O:SPY250829C00650000          call       american
# 22314  2025-08-20  O:SPY260116P00575000           put       american
# 56186  2025-08-26  O:SPY260116P00575000           put       american
#
#       expiration_date  shares_per_contract  strike_price  day_change  \
# ...

# %%
df5.to_csv('top100.csv', index=False)

# %%
df4.shape
# Out:
# (721, 29)
