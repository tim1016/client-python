# %%
import pandas as pd

# %%
df= pd.read_csv('')

# %%
df= pd.read_csv('bucket_gap_analysis_GLD_2025-08-22_to_2025-08-29/pattern_summary.csv')

# %%
df
# Out:
#    pattern  occurrences  total_change  avg_total_change  avg_internal_change  \
# 0    PPPPP           77        9.9379            0.1291               0.1300
# 1    NPPPP           31        3.1037            0.1001               0.0875
# 2    PNPPP           33        2.1586            0.0654               0.0746
# 3    PPNPP           35        1.8641            0.0533               0.0311
# 4    NPPPN           25        1.7700            0.0708               0.0648
# 5    NPPNP           21        1.7207            0.0819               0.0851
# 6    PPPPN           44        1.5199            0.0345               0.0425
# 7    PPPNP           38        0.9215            0.0242               0.0326
# 8    PNNPP           20        0.7118            0.0356               0.0272
# 9    PPNNP           19        0.5900            0.0311              -0.0086
# 10   PPPNN           23        0.5146            0.0224               0.0114
# ...

# %%
profit = df.loc[:,'total_change']

# %%
profit.sum()
# Out:
# np.float64(11.22)

# %%
318.07 - 306.8
# Out:
# 11.269999999999982

# %%
df=pd.read_csv('combined_pattern_analysis.csv')

# %%
df
# Out:
#    pattern  offset_0  offset_1  offset_2  offset_3  offset_4
# 0    NNNNN   -1.0150   -1.9650   -1.5194   -0.9500   -0.9863
# 1    NNNNP   -0.5800   -0.8385   -0.6638   -0.8062   -0.8359
# 2    NNNPN   -1.5589   -0.8372   -0.7998   -0.7473   -0.9349
# 3    NNNPP   -0.6234   -1.1700   -0.7030   -0.8480   -0.5308
# 4    NNPNN   -1.4982   -1.3625   -0.9366   -1.4356   -0.6738
# 5    NNPNP   -0.3498   -0.8270   -0.5563   -0.4849   -1.5815
# 6    NNPPN   -1.7301   -1.1789   -0.3350   -0.6985   -0.6201
# 7    NNPPP    0.5142    0.3680    0.1151    0.6587    1.3057
# 8    NPNNN   -0.6856   -0.7380   -0.9692   -2.0863   -1.7824
# 9    NPNNP   -0.5426   -0.6191   -0.7166   -0.6925   -0.3207
# 10   NPNPN   -0.9127   -1.0666   -0.7519   -1.0367   -0.8924
# 11   NPNPP    0.1969    0.9500   -0.8358    1.5097    0.3410
# 12   NPPNN   -0.4638   -0.9849   -1.2902   -0.3889   -1.1427
# 13   NPPNP    1.7207   -0.7076    0.7365    0.8893   -0.1656
# ...
